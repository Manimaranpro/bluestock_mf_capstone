# %%
import sqlite3
conn = sqlite3.connect("../data/db/bluestock_mf.db")
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('monthly_sip_inflows',), ('category_inflows',), ('industry_folio_count',), ('portfolio_holdings',), ('dim_fund',), ('dim_date',), ('fact_nav',), ('fact_transactions',), ('fact_performance',), ('fact_aum',)]

# %%
import os

reports_dir = os.path.join("..", "reports")
os.makedirs(reports_dir, exist_ok=True)

html_content = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Capstone Project I Final Report</title>
    <style>
        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            color: #333333;
            line-height: 1.6;
            margin: 40px;
            background-color: #FAFAFA;
        }
        .container {
            max-width: 900px;
            margin: auto;
            background: #FFFFFF;
            padding: 40px;
            box-shadow: 0 4px 10px rgba(0, 0, 0, 0.05);
            border-radius: 8px;
        }
        h1 {
            color: #1F4E79;
            border-bottom: 2px solid #1F4E79;
            padding-bottom: 10px;
            font-size: 28px;
        }
        h2 {
            color: #2F5597;
            margin-top: 30px;
            font-size: 20px;
            border-bottom: 1px solid #D9D9D9;
            padding-bottom: 5px;
        }
        h3 {
            color: #41719C;
            font-size: 16px;
        }
        .meta-table {
            width: 100%;
            border-collapse: collapse;
            margin-bottom: 30px;
        }
        .meta-table td {
            padding: 8px;
            border: 1px solid #D9D9D9;
        }
        .meta-table td.label {
            font-weight: bold;
            background-color: #F2F2F2;
            width: 30%;
        }
        .chart-box {
            text-align: center;
            margin: 35px 0;
            padding: 15px;
            border: 1px solid #E0E0E0;
            background-color: #FCFCFC;
            border-radius: 6px;
        }
        .chart-box img {
            max-width: 100%;
            height: auto;
            border-radius: 4px;
        }
        .chart-title {
            font-weight: bold;
            margin-top: 10px;
            color: #2F5597;
        }
        .bullet-list {
            margin-left: 20px;
            padding-left: 0;
        }
        .bullet-list li {
            margin-bottom: 8px;
        }
        .footer {
            margin-top: 50px;
            text-align: center;
            font-size: 12px;
            color: #7F7F7F;
            border-top: 1px solid #D9D9D9;
            padding-top: 15px;
        }
    </style>
</head>
<body>

<div class="container">
    <div style="text-align: center; margin-bottom: 40px;">
        <h1 style="border: none; margin-bottom: 5px; color: #1F4E79;">MUTUAL FUND ANALYTICS PLATFORM</h1>
        <p style="font-size: 16px; color: #7F7F7F; margin-top: 0;">Capstone Project I - Final Implementation Report</p>
    </div>

    <table class="meta-table">
        <tr>
            <td class="label">Student Name</td>
            <td>Manimaran A</td>
        </tr>
        <tr>
            <td class="label">Education</td>
            <td>B.E. Artificial Intelligence and Machine Learning (AIML)</td>
        </tr>
        <tr>
            <td class="label">Internship Role</td>
            <td>Data Analyst Intern</td>
        </tr>
        <tr>
            <td class="label">Organization</td>
            <td>Bluestock Fintech</td>
        </tr>
        <tr>
            <td class="label">GitHub Repository</td>
            <td><a href="https://github.com/Manimaranpro/bluestock_mf_capstone" target="_blank">https://github.com/Manimaranpro/bluestock_mf_capstone</a></td>
        </tr>
    </table>

    <h2>1. Executive Summary</h2>
    <p>This report documents the end-to-end design and implementation of the Mutual Fund Analytics Platform. The objective of the platform is to ingest, clean, store, and analyze mutual fund transactional datasets, daily NAV history, and portfolio holdings. By utilizing advanced Python algorithms, relational database architectures, and analytical reports, the platform provides robust quantitative insights into portfolio performance and risk parameters.</p>

    <h2>2. Technical Architecture & ETL Pipeline</h2>
    <ul class="bullet-list">
        <li><strong>Ingestion & Cleaning</strong>: Automated pipelines parsed and standardized date representations, applied forward-fill logic across holidays to eliminate missing valuations, and enforced integrity checks on financial variables.</li>
        <li><strong>Relational DB Migration</strong>: Built a relational SQLite database (<code>bluestock_mf.db</code>) incorporating a 3NF Star Schema with strict primary/foreign key connections linking central fact tables to dimension tables.</li>
        <li><strong>SQL Analytics</strong>: Drafted and verified 10 core analytical queries evaluating crucial business questions (including category averages, asset-under-management rankings, and expense limits).</li>
    </ul>

    <h2>3. Quantitative Portfolio Analytics</h2>
    <p>Using vectorized matrix calculations, the platform generated advanced investment risk-and-return metrics across all 40 schemes, avoiding slow nested iterations. The metrics include annualized Compound Annual Growth Rate (CAGR), Sharpe Ratios, Sortino Ratios, Maximum Drawdowns, and systematic risk coefficients (Alpha and Beta) calculated via OLS regressions against Nifty benchmarks.</p>

    <h2>4. Visual Findings & Analytical Artifacts</h2>

    <div class="chart-box">
        <img src="../dashboard/01_nav_trends.png" alt="NAV Trends Chart">
        <div class="chart-title">Figure 1: Daily NAV Historical Trend (2022-2026)</div>
        <p style="font-size: 13px; color: #555; margin: 10px 20px;">Displays the daily NAV trajectory for schemes, highlighting market bull runs and corrections.</p>
    </div>

    <div class="chart-box">
        <img src="../dashboard/02_aum_growth.png" alt="AUM Growth Chart">
        <div class="chart-title">Figure 2: Annual AUM Growth Comparison</div>
        <p style="font-size: 13px; color: #555; margin: 10px 20px;">Compares Assets Under Management (AUM) across fund houses, illustrating market dominance.</p>
    </div>

    <div class="chart-box">
        <img src="../dashboard/benchmark_comparison.png" alt="Benchmark Comparison Chart">
        <div class="chart-title">Figure 3: Top 5 Scorecard Funds vs. Nifty Benchmark</div>
        <p style="font-size: 13px; color: #555; margin: 10px 20px;">Tracks the normalized growth of the top 5 scorecard-selected funds against the market index.</p>
    </div>

    <h2>5. Conclusion</h2>
    <p>The platform successfully automates the translation of raw financial transaction logs into structured, actionable business intelligence. The implementation of robust data structures, documented data dictionaries, and automated visual reports ensures the pipeline is reproducible, secure, and ready for production deployment.</p>

    <div class="footer">
        © 2026 Bluestock Fintech Capstone Submission | Compiled by Manimaran A
    </div>
</div>

</body>
</html>"""

with open(os.path.join(reports_dir, "final_report.html"), "w", encoding="utf-8") as f:
    f.write(html_content)

print("SUCCESS: reports/final_report.html created automatically with CSS styling and embedded charts!")
# Out:
# SUCCESS: reports/final_report.html created automatically with CSS styling and embedded charts!
